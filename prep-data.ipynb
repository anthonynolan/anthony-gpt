# %%
from datasets import load_dataset

ds = load_dataset("stanfordnlp/sst2")

print(ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['idx', 'sentence', 'label'],
#         num_rows: 67349
#     })
#     validation: Dataset({
#         features: ['idx', 'sentence', 'label'],
#         num_rows: 872
#     })
#     test: Dataset({
#         features: ['idx', 'sentence', 'label'],
#         num_rows: 1821
#     })
# })

# %%
import pandas as pd

train = pd.DataFrame(ds['train'].shuffle(seed=23487)).set_index('idx')
train
# Out:
#                                                 sentence  label
# idx
# 55109                              uplifting and moving       1
# 54429  a kid who ca n't quite distinguish one sci-fi ...      0
# 24067                                        as ` wayne       1
# 38695  safe conduct is so rich with period minutiae i...      1
# 41114                 wo n't hold up over the long haul       0
# ...                                                  ...    ...
# 49850  at its best , which occurs often , michael moo...      1
# 26593                                    pretty moments       1
# 26352                              his characters stage       1
# 32505  maybe it is formula filmmaking , but there 's ...      1
# 62252  is a matter of plumbing arrangements and mind ...      0
#
# [67349 rows x 2 columns]
